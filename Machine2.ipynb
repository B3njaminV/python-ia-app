# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os
from PIL import Image

# %%
Image_Width=128
Image_Height=128
Image_Size=(Image_Width,Image_Height)
Image_Channels=3

# %%
filenames=os.listdir("./traincc")
categories=[]
for f_name in filenames:
    category=f_name.split('.')[0]
    if category=='dog':
        categories.append(1)
    else:
        categories.append(0)
df=pd.DataFrame({
    'filename':filenames,
    'category':categories
})

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,\
     Dropout,Flatten,Dense,Activation,\
     BatchNormalization
model=Sequential()
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(Image_Width,Image_Height,Image_Channels)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2,activation='softmax'))
model.compile(loss='categorical_crossentropy',
  optimizer='rmsprop',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  batch_normalization (BatchN  (None, 126, 126, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  dropout (Dropout)           (None, 63, 63, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 61, 61, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 28, 28, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 14, 14, 128)       0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 512)               12845568
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 2)                 1026
#
# =================================================================
# Total params: 12,942,786
# Trainable params: 12,941,314
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
earlystop = EarlyStopping(patience = 10)
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_acc',patience = 2,verbose = 1,factor = 0.5,min_lr = 0.00001)
callbacks = [earlystop,learning_rate_reduction]

# %%
df["category"] = df["category"].replace({0:'cat',1:'dog'})
train_df,validate_df = train_test_split(df,test_size=0.20,
  random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)
total_train=train_df.shape[0]
total_validate=validate_df.shape[0]
batch_size=15

# %%
train_datagen = ImageDataGenerator(rotation_range=15,
                                rescale=1./255,
                                shear_range=0.1,
                                zoom_range=0.2,
                                horizontal_flip=True,
                                width_shift_range=0.1,
                                height_shift_range=0.1
                                )
train_generator = train_datagen.flow_from_dataframe(train_df,
                                                 "./traincc/",x_col='filename',y_col='category',
                                                 target_size=Image_Size,
                                                 class_mode='categorical',
                                                 batch_size=batch_size)
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df,
    "./traincc/",
    x_col='filename',
    y_col='category',
    target_size=Image_Size,
    class_mode='categorical',
    batch_size=batch_size
)
test_datagen = ImageDataGenerator(rotation_range=15,
                                rescale=1./255,
                                shear_range=0.1,
                                zoom_range=0.2,
                                horizontal_flip=True,
                                width_shift_range=0.1,
                                height_shift_range=0.1)
test_generator = train_datagen.flow_from_dataframe(train_df,
                                                 "./testcc/",x_col='filename',y_col='category',
                                                 target_size=Image_Size,
                                                 class_mode='categorical',
                                                 batch_size=batch_size)
# Out:
# Found 65 validated image filenames belonging to 2 classes.
# Found 17 validated image filenames belonging to 2 classes.
# Found 65 validated image filenames belonging to 2 classes.

# %%
epochs=40
history = model.fit_generator(
    train_generator,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# c:\users\benja\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:8: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 3s 618ms/step - loss: 0.5601 - accuracy: 0.8200 - val_loss: 8.8305 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 2/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 3s 621ms/step - loss: 0.7647 - accuracy: 0.7500 - val_loss: 8.3453 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 3/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 591ms/step - loss: 0.8655 - accuracy: 0.8200 - val_loss: 10.0687 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 4/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 3s 629ms/step - loss: 0.6764 - accuracy: 0.7800 - val_loss: 8.9243 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 5/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 3s 930ms/step - loss: 0.4577 - accuracy: 0.8000 - val_loss: 9.1583 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 6/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 3s 708ms/step - loss: 0.9049 - accuracy: 0.7000 - val_loss: 6.7945 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 7/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 3s 696ms/step - loss: 0.2052 - accuracy: 0.9000 - val_loss: 7.4697 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 8/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 571ms/step - loss: 0.2422 - accuracy: 0.9000 - val_loss: 8.3363 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 9/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 642ms/step - loss: 0.5579 - accuracy: 0.7400 - val_loss: 8.2415 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 10/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 550ms/step - loss: 0.3985 - accuracy: 0.8600 - val_loss: 7.2294 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 11/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 577ms/step - loss: 0.5003 - accuracy: 0.8167 - val_loss: 6.1104 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 12/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 578ms/step - loss: 0.7048 - accuracy: 0.7500 - val_loss: 6.7544 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 13/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 542ms/step - loss: 0.2310 - accuracy: 0.9000 - val_loss: 8.8868 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 14/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 530ms/step - loss: 0.2853 - accuracy: 0.9000 - val_loss: 9.3333 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 15/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 601ms/step - loss: 0.4250 - accuracy: 0.8500 - val_loss: 7.5603 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 16/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 592ms/step - loss: 0.4067 - accuracy: 0.8500 - val_loss: 3.3952 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 17/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 563ms/step - loss: 0.2843 - accuracy: 0.8800 - val_loss: 4.7370 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 18/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 4s 1s/step - loss: 0.3457 - accuracy: 0.8167 - val_loss: 3.6327 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 19/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 540ms/step - loss: 0.3169 - accuracy: 0.8400 - val_loss: 2.5371 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 20/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 579ms/step - loss: 0.2788 - accuracy: 0.8667 - val_loss: 5.3956 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 21/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 537ms/step - loss: 0.4658 - accuracy: 0.7800 - val_loss: 5.8148 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 22/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 559ms/step - loss: 0.4653 - accuracy: 0.8333 - val_loss: 4.2904 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 23/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 548ms/step - loss: 0.2218 - accuracy: 0.9000 - val_loss: 1.7011 - val_accuracy: 0.5333 - lr: 0.0010
# Epoch 24/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 547ms/step - loss: 0.2455 - accuracy: 0.9167 - val_loss: 1.7743 - val_accuracy: 0.4667 - lr: 0.0010
# Epoch 25/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 518ms/step - loss: 0.5977 - accuracy: 0.8000 - val_loss: 5.5609 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 26/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 516ms/step - loss: 0.4260 - accuracy: 0.8000 - val_loss: 5.9867 - val_accuracy: 0.2667 - lr: 0.0010
# Epoch 27/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 565ms/step - loss: 0.5723 - accuracy: 0.7800 - val_loss: 5.2472 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 28/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 3s 804ms/step - loss: 0.2116 - accuracy: 0.9333 - val_loss: 7.8236 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 29/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 583ms/step - loss: 0.4445 - accuracy: 0.8400 - val_loss: 8.7890 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 30/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 583ms/step - loss: 0.4183 - accuracy: 0.8800 - val_loss: 9.8554 - val_accuracy: 0.2667 - lr: 0.0010
# Epoch 31/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 3s 698ms/step - loss: 0.3355 - accuracy: 0.8800 - val_loss: 10.9251 - val_accuracy: 0.4000 - lr: 0.0010
# Epoch 32/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 2s 556ms/step - loss: 0.5532 - accuracy: 0.7400 - val_loss: 8.4026 - val_accuracy: 0.3333 - lr: 0.0010
# Epoch 33/40
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 4/4 [==============================] - 3s 663ms/step - loss: 0.2737 - accuracy: 0.8800 - val_loss: 11.1500 - val_accuracy: 0.3333 - lr: 0.0010

# %%
test_filenames = os.listdir("./testcc")
test_df = pd.DataFrame({
    'filename': test_filenames
})
nb_samples = test_df.shape[0]

# %%
predict = model.predict_generator(test_generator, steps=np.ceil(nb_samples/batch_size))
# Out:
# c:\users\benja\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   """Entry point for launching an IPython kernel.
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 6.0 batches). You may need to use the repeat() function when building your dataset.

# %%
test_df['category'] = np.argmax(predict)
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category'] = test_df['category'].replace(label_map)
test_df['category'] = test_df['category'].replace({ 'dog': 1, 'cat': 0 })

# %%
sample_test = test_df.head(18)
sample_test.head()
plt.figure(figsize=(12, 24))
for index, row in sample_test.iterrows():
    filename = row['filename']
    category = row['category']
    img = load_img("./testcc/"+filename, target_size=Image_Size)
    plt.subplot(6, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + '(' + "{}".format(category) + ')' )
plt.tight_layout()
plt.show()

# %%
results={
    0:'cat',
    1:'dog'
}

im=Image.open("./testcc/dog.3.jpg")
im=im.resize(Image_Size)
im=np.expand_dims(im,axis=0)
im=np.array(im)
im=im/255
pred=np.argmax(model.predict([im])[0], axis=-1)
print(pred,results[pred])
# Out:
# 1 dog
# 1 dog
